# %%
import pandas as pd

# %%
df=pd.read_csv("https___www.amazon.com_s_k=mob.csv")

# %%
df.head()
# Out:
#                                   a-link-normal href  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...
# 1  https://www.amazon.com/Samsung-Electronics-Unl...
# 2  https://www.amazon.com/Samsung-A20S-Cameras-Sn...
# 3  https://www.amazon.com/Nokia-Unlocked-Smartpho...
# 4  https://www.amazon.com/OnePlus-Ultramarine-Unl...
#
#                                          s-image src s-label-popover href  \
# 0  https://m.media-amazon.com/images/I/61sUPaDzNq...   javascript:void(0)
# 1  https://m.media-amazon.com/images/I/813y2+dPUO...                  NaN
# 2  https://m.media-amazon.com/images/I/41yVqjvkLc...                  NaN
# 3  https://m.media-amazon.com/images/I/61sLvszoET...                  NaN
# 4  https://m.media-amazon.com/images/I/410mmBW-AY...                  NaN
#
#   a-size-mini                                  a-popover-preload  \
# 0   Sponsored  You’re seeing this ad based on the product’s r...
# 1         NaN                                                NaN
# ...
